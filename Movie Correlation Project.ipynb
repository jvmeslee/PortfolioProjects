# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots we will create

#reading data
df = pd.read_csv(r'C:\Users\jjael\Downloads\movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#Checking for Null values and dropping them
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
    
df = df.dropna()
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
#Checking the data types of the database
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change datatype to int
df['gross'] = df['gross'].astype('int')
df['votes'] = df['votes'].astype('int')
df['runtime'] = df['runtime'].astype('int')
df['budget'] = df['budget'].astype('int')

# %%
# some of the years are incorrect therefore creating a correct year column
df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)

# %%
# sorting by gross(top 5 highest gross movies)
df.sort_values(by=['gross'], inplace=False, ascending=False).head()
# Out:
#                                             name rating      genre  year  \
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13     Action  2015
# 7244                      Avengers: Infinity War  PG-13     Action  2018
# 7480                               The Lion King     PG  Animation  2019
# 6653                              Jurassic World  PG-13     Action  2015
# 6043                                The Avengers  PG-13     Action  2012
#
#                                released  score    votes         director  \
# 6663  December 18, 2015 (United States)    7.8   876000      J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000    Anthony Russo
# 7480      July 19, 2019 (United States)    6.9   222000      Jon Favreau
# 6653      June 12, 2015 (United States)    7.0   593000  Colin Trevorrow
# 6043        May 4, 2012 (United States)    8.0  1300000      Joss Whedon
#
#                   writer               star        country     budget  \
# ...

# %%
#dropping duplicates
df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 3698                              Zentropa Entertainments
# 1180                                 Zenith Entertainment
# 5180                                      Zazen Produções
# 1321                             Zanuck/Brown Productions
# 1329                          Zacharias-Buhai Productions
# 789                             Young Sung Production Co.
# 5125                           Young Hannibal Productions
# ...

# %%
# Predicting a high correlation with budget and company modified data b/ of negative gross values
sns.regplot(x='budget', y='gross', data=df.sort_values(by=['gross'], inplace=False, ascending=True).iloc[3:], scatter_kws={'color':'red'},line_kws={'color':'blue'})
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget for Film')
plt.ylabel('Gross Earnings')
# Out:
# Text(0, 0.5, 'Gross Earnings')

# %%
#checking correlation values
df.corr(method = 'pearson') # different types of correlation methods spearman, kendall, pearson(is the default)
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.056386  0.206021  0.327722  0.267631  0.075077
# score        0.056386  1.000000  0.474256  0.072001  0.201086  0.414068
# votes        0.206021  0.474256  1.000000  0.439675  0.550649  0.352303
# budget       0.327722  0.072001  0.439675  1.000000  0.669203  0.318695
# gross        0.267631  0.201086  0.550649  0.669203  1.000000  0.223667
# runtime      0.075077  0.414068  0.352303  0.318695  0.223667  1.000000
# yearcorrect  0.998726  0.061923  0.203098  0.320312  0.262186  0.075294
#
#              yearcorrect
# year            0.998726
# score           0.061923
# votes           0.203098
# budget          0.320312
# gross           0.262186
# runtime         0.075294
# yearcorrect     1.000000

# %%
#creating heatmap
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix for Numeric Features')

# %%
#checking correlation of other string values
df_numerized = df.copy()
for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized.head()
# Out:
#    name  rating  genre  year  released  score    votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000       757    1818
# 3   204       4      4  1980      1127    7.7   221000       889    1413
# 4   732       6      4  1980      1170    7.3   108000       719     351
#
#    star  country    budget      gross  company  runtime  yearcorrect
# 0   699       46  19000000   46998772     1426      146         1980
# 1   214       47   4500000   58853106      452      104         1980
# 2  1157       47  18000000  538375067      945      124         1980
# 3  1474       47   3500000   83453539     1108       88         1980
# 4   271       47   6000000   39846344     1083       98         1980

# %%
# creating heatmap
correlation_matrix = df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix for Numeric Features')

# %%
# checking correlation of values
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating      -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre        0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year         0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released    -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score        0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes        0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director     0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer       0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star        -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country     -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget       0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
# checking that high correlated values
correlation_matrix = df_numerized.corr()
corr_pairs = correlation_matrix.unstack()
sorted_pairs = corr_pairs.sort_values()
high_corr = sorted_pairs[(sorted_pairs > 0.5)]
high_corr
# Out:
# gross        votes          0.550649
# votes        gross          0.550649
# budget       gross          0.669203
# gross        budget         0.669203
# year         yearcorrect    0.998726
# yearcorrect  year           0.998726
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# We can conclude that votes and budget have the highest correlation
